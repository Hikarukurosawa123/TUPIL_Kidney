# %%
# main_run.py
import os 
from Converted_python_scripts.rf_image_func import rf_image

from Converted_python_scripts.rf_fft_func import plot_group_ffts
from Converted_python_scripts.rf_fft_func import plot_group_ffts_avg
from Converted_python_scripts.rf_fft_func import rf_roi_fft_parametric

# Path to your dataset
root_dir = "data/Raw_data"

# Example call
# Replace patient_id and image_num with valid ones in your dataset
rf_image(patient_id=9, image_num=3, root_dir=root_dir)

csv_file = os.path.join("csv", "patient_eGFR_at_pocus_2025_Jul_polynomial_estimation.csv")
#plot_group_ffts(root_dir, csv_file)
plot_group_ffts_avg(root_dir, csv_file)
# Out:
# P9_PTOR_01_May_31-23-REB16236-009
# data/Raw_data/P9_PTOR_01_May_31-23-REB16236-009/P9_Image_3/P9_PTOR_01_Image_3_rf.raw
# hinfo 2
# Data shape: (14, 2128, 144)
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# Skipping P363_Image_5: Expecting miMATRIX type here, got 1145132152
# Skipping P363_Image_4: Expecting miMATRIX type here, got 1145132152
# hinfo 2
# Skipping P363_Image_1: Expecting miMATRIX type here, got 1145132152
# Skipping P27_Image_4: [Errno 2] No such file or directory: 'data/Raw_data/P27_PTONR_01_Jun_13-23-REB16236-027/P27_Image_4/ROIs'
# Skipping P27_Image_3: [Errno 2] No such file or directory: 'data/Raw_data/P27_PTONR_01_Jun_13-23-REB16236-027/P27_Image_3/ROIs'
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# hinfo 2
# ...

# %%
import matplotlib.pyplot as plt
MBF_map, SI_map, depth_axis, width_axis= rf_roi_fft_parametric(9, 3, root_dir)
# Out:
# hinfo 2
